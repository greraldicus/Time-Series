# %%
import matplotlib.pyplot as plt
import numpy as np
import random

myseed = 42
random.seed(myseed)
np.random.seed(myseed)

# %%
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

# %%
time = np.linspace(-5, 5, num=100)
N = 7
timeseries = {'time': time}
rand = np.random.random(size=7)

for i in range(N):
    timeseries[f'arctan{i}'] = np.arctan(time + rand[i])
for i in range(N):
    timeseries[f'tanh{i}'] = np.tanh(time + rand[i])
for i in range(N):
    timeseries[f'sigmoid{i}'] = sigmoid(time + rand[i])

for i in range(N):
    plt.plot(time, timeseries[f'arctan{i}'], '-b')
for i in range(N):
    plt.plot(time, timeseries[f'tanh{i}'], '-g')
for i in range(N):
    plt.plot(time, timeseries[f'sigmoid{i}'], '-r')

plt.show()

# %%
from scipy.spatial.distance import euclidean

euclidean_dist = np.array([])

for i in range(1, 4):
    x = np.abs(timeseries[f"arctan{i}"])
    y = np.abs(timeseries[f"arctan{i - 1}"])
    distance = euclidean(x, y)
    euclidean_dist = np.append(euclidean_dist, distance)
    print(f"расстояние euclidean для объектов arctan {i} и {7 - i}:", distance)

for i in range(1, 4):
    x = np.abs(timeseries[f"sigmoid{i}"])
    y = np.abs(timeseries[f"sigmoid{i - 1}"])
    distance = euclidean(x, y)
    euclidean_dist = np.append(euclidean_dist, distance)
    print(f"расстояние euclidean для объектов sigmoid {i} и {7 - i}:", distance)

for i in range(1, 4):
    x = np.abs(timeseries[f"tanh{i}"])
    y = np.abs(timeseries[f"tanh{i - 1}"])
    distance = euclidean(x, y)
    euclidean_dist = np.append(euclidean_dist, distance)
    print(f"расстояние euclidean для объектов tanh {i} и {7 - i}:", distance)

x = np.abs(timeseries[f"arctan1"])
y = np.abs(timeseries[f"sigmoid1"])
distance = euclidean(x, y)
euclidean_dist = np.append(euclidean_dist, distance)
print(f"расстояние euclidean для объектов arctan1 и sigmoid1:", distance)

x = np.abs(timeseries[f"arctan1"])
y = np.abs(timeseries[f"sigmoid1"])
distance = euclidean(x, y)
euclidean_dist = np.append(euclidean_dist, distance)
print(f"расстояние euclidean для объектов tanh1 и sigmoid1:", distance)

x = np.abs(timeseries["tanh1"])
y = np.abs(timeseries["arctan1"])
distance = euclidean(x, y)
euclidean_dist = np.append(euclidean_dist, distance)
print(f"расстояние euclidean для объектов tanh1 и arctan1:", distance)
# Out:
# расстояние euclidean для объектов arctan 1 и 6: 1.9746974480824244
# расстояние euclidean для объектов arctan 2 и 5: 0.8209358717284354
# расстояние euclidean для объектов arctan 3 и 4: 0.5078267678585604
# расстояние euclidean для объектов sigmoid 1 и 6: 0.7378920455175161
# расстояние euclidean для объектов sigmoid 2 и 5: 0.2807465958355427
# расстояние euclidean для объектов sigmoid 3 и 4: 0.17120577193701533
# расстояние euclidean для объектов tanh 1 и 6: 1.7646669497039122
# расстояние euclidean для объектов tanh 2 и 5: 0.7507830961228192
# расстояние euclidean для объектов tanh 3 и 4: 0.4658085717121996
# расстояние euclidean для объектов arctan1 и sigmoid1: 6.498860329608626
# расстояние euclidean для объектов tanh1 и sigmoid1: 6.498860329608626
# расстояние euclidean для объектов tanh1 и arctan1: 2.3520658120703795

# %%
# !pip install dtaidistance
# Out:
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dtaidistance) (1.23.5)
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.11

# %%
from dtaidistance import dtw

dtw_dist = np.array([])

for i in range(1, 4):
    x = np.abs(timeseries[f"arctan{i}"])
    y = np.abs(timeseries[f"arctan{i - 1}"])
    distance = dtw.distance(x, y)
    dtw_dist = np.append(dtw_dist, distance)
    print(f"расстояние dtw для объектов arctan {i} и {7 - i}:", distance)

for i in range(1, 4):
    x = np.abs(timeseries[f"sigmoid{i}"])
    y = np.abs(timeseries[f"sigmoid{i - 1}"])
    distance = dtw.distance(x, y)
    dtw_dist = np.append(dtw_dist, distance)
    print(f"расстояние dtw для объектов sigmoid {i} и {7 - i}:", distance)

for i in range(1, 4):
    x = np.abs(timeseries[f"tanh{i}"])
    y = np.abs(timeseries[f"tanh{i - 1}"])
    distance = dtw.distance(x, y)
    dtw_dist = np.append(dtw_dist, distance)
    print(f"расстояние dtw для объектов tanh {i} и {7 - i}:", distance)

x = np.abs(timeseries[f"arctan1"])
y = np.abs(timeseries[f"sigmoid1"])
distance = dtw.distance(x, y)
dtw_dist = np.append(dtw_dist, distance)
print(f"расстояние dtw для объектов arctan1 и sigmoid1:", distance)

x = np.abs(timeseries[f"tanh1"])
y = np.abs(timeseries[f"sigmoid1"])
distance = dtw.distance(x, y)
dtw_dist = np.append(dtw_dist, distance)
print(f"расстояние dtw для объектов tanh1 и sigmoid1:", distance)

x = np.abs(timeseries["tanh1"])
y = np.abs(timeseries["arctan1"])
distance = dtw.distance(x, y)
dtw_dist = np.append(dtw_dist, distance)
print(f"расстояние dtw для объектов tanh1 и arctan1:", distance)
# Out:
# расстояние dtw для объектов arctan 1 и 6: 0.12660124673988454
# расстояние dtw для объектов arctan 2 и 5: 0.06750534726298121
# расстояние dtw для объектов arctan 3 и 4: 0.12748514313123835
# расстояние dtw для объектов sigmoid 1 и 6: 0.04040466305647928
# расстояние dtw для объектов sigmoid 2 и 5: 0.021791459997690873
# расстояние dtw для объектов sigmoid 3 и 4: 0.0415487370842471
# расстояние dtw для объектов tanh 1 и 6: 0.10509010497574434
# расстояние dtw для объектов tanh 2 и 5: 0.06067464957572626
# расстояние dtw для объектов tanh 3 и 4: 0.11743979340526961
# расстояние dtw для объектов arctan1 и sigmoid1: 6.384167749459408
# расстояние dtw для объектов tanh1 и sigmoid1: 4.9163391944098755
# расстояние dtw для объектов tanh1 и arctan1: 2.301709428887394

# %%
diff = euclidean_dist - dtw_dist
print("на сколько в среднем евклидова метрика больше dtw: ", np.mean(diff))
print(diff)
# Out:
# на сколько в среднем евклидова метрика больше dtw:  0.7094660059833432
# [1.8480962  0.75343052 0.38034162 0.69748738 0.25895514 0.12965703
#  1.65957684 0.69010845 0.34836878 0.11469258 1.58252114 0.05035638]

# %% [markdown]
# Вывод: Для наших классов метрика DTW показывает более точный результат, чем евклидова

# %% [markdown]
# **Формируем набор данных для обучения**

# %%
X = []
Y = []
for v in timeseries:
    if v!= 'time':
        X.append(timeseries[v])
        c = v[:-1]
        if c == "sigmoid":
            Y.append(1)
        elif c == "arctan":
            Y.append(2)
        else: Y.append(3)
Y
# Out:
# [2, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# **train/test**

# %%
arr = np.arange(len(Y))
np.random.shuffle(arr)

X_train = []
X_test = []
Y_train = []
Y_test = []

for i in arr[:-6]:
    X_train.append(X[i])
    Y_train.append(Y[i])
for i in arr[len(X_train):]:
    X_test.append(X[i])
    Y_test.append(Y[i])

Y_train, Y_test
# Out:
# ([1, 1, 2, 1, 3, 3, 1, 3, 3, 2, 2, 1, 2, 3, 3], [1, 2, 2, 3, 2, 1])

# %% [markdown]
# **Обучение**

# %%
# dtw метрика
from pyts.classification import KNeighborsClassifier

clf = KNeighborsClassifier(metric='dtw')
clf.fit(X_train, Y_train)

print(f"Accuracy {clf.score(X_test, Y_test)}")
for i in range(len(Y_test)):
    print(f"{i + 1} объект:")
    print(f"Вектор вероятности принадлежности к классам {clf.predict_proba(X_test[i].reshape(1, -1))}")
    print(f"Истинный класс для предсказаний {Y_test[i]}")
# Out:
# Accuracy 1.0
# 1 объект:
# Вектор вероятности принадлежности к классам [[1. 0. 0.]]
# Истинный класс для предсказаний 1
# 2 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 3 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 4 объект:
# Вектор вероятности принадлежности к классам [[0. 0. 1.]]
# Истинный класс для предсказаний 3
# 5 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 6 объект:
# Вектор вероятности принадлежности к классам [[1. 0. 0.]]
# Истинный класс для предсказаний 1

# %%
# стандартная метрика
clf = KNeighborsClassifier()
clf.fit(X_train, Y_train)

print(f"Accuracy {clf.score(X_test, Y_test)}")
for i in range(len(Y_test)):
    print(f"{i + 1} объект:")
    print(f"Вектор вероятности принадлежности к классам {clf.predict_proba(X_test[i].reshape(1, -1))}")
    print(f"Истинный класс для предсказаний {Y_test[i]}")
# Out:
# Accuracy 1.0
# 1 объект:
# Вектор вероятности принадлежности к классам [[1. 0. 0.]]
# Истинный класс для предсказаний 1
# 2 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 3 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 4 объект:
# Вектор вероятности принадлежности к классам [[0. 0. 1.]]
# Истинный класс для предсказаний 3
# 5 объект:
# Вектор вероятности принадлежности к классам [[0. 1. 0.]]
# Истинный класс для предсказаний 2
# 6 объект:
# Вектор вероятности принадлежности к классам [[1. 0. 0.]]
# Истинный класс для предсказаний 1

# %%
# forest
from pyts.classification import TimeSeriesForest

clf = TimeSeriesForest(random_state=43)
clf.fit(X_train, Y_train)


print(f"Accuracy {clf.score(X_test, Y_test)}")
for i in range(len(Y_test)):
    print(f"{i + 1} объект:")
    print(f"Вектор вероятности принадлежности к классам {clf.predict_proba(X_test[i].reshape(1, -1))}")
    print(f"Истинный класс для предсказаний {Y_test[i]}")
# Out:
# Accuracy 1.0
# 1 объект:
# Вектор вероятности принадлежности к классам [[0.972 0.002 0.026]]
# Истинный класс для предсказаний 1
# 2 объект:
# Вектор вероятности принадлежности к классам [[0.25  0.582 0.168]]
# Истинный класс для предсказаний 2
# 3 объект:
# Вектор вероятности принадлежности к классам [[0.152 0.716 0.132]]
# Истинный класс для предсказаний 2
# 4 объект:
# Вектор вероятности принадлежности к классам [[0.002 0.022 0.976]]
# Истинный класс для предсказаний 3
# 5 объект:
# Вектор вероятности принадлежности к классам [[0.078 0.822 0.1  ]]
# Истинный класс для предсказаний 2
# 6 объект:
# Вектор вероятности принадлежности к классам [[0.942 0.004 0.054]]
# Истинный класс для предсказаний 1

# %% [markdown]
# **Итог: Все классификаторы правильно предсказали принадлежность объектов к классам**
